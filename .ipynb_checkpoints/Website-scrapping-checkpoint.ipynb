# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
#importing oscar winners films

# %%
url1 = 'https://www.today.com/popculture/complete-list-every-best-picture-oscar-winner-ever-t107617'

# %%
res1 = requests.get("https://www.today.com/popculture/complete-list-every-best-picture-oscar-winner-ever-t107617")
html1 = res.text
soup1 = BeautifulSoup(html1, 'html.parser')
# print(soup1)

# Think we must use Selenium to scrap films by year
# Out:
# <!DOCTYPE html>
# ...

# %%
#importing oscar winners directors

# %%
url2 = 'https://www.today.com/popculture/complete-list-every-best-picture-oscar-winner-ever-t107617'

# %%
res2 = requests.get("https://www.today.com/popculture/complete-list-every-best-picture-oscar-winner-ever-t107617")
html2 = res2.text
soup2 = BeautifulSoup(html2, 'html.parser')
print(soup2)
